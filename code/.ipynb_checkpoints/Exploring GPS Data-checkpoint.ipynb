# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import warnings

warnings.simplefilter('ignore')
# %matplotlib inline

# %%
rpe_df = pd.read_csv("../data/rpe.csv")
games_df = pd.read_csv("../data/games.csv")
gps_df = pd.read_csv("../data/gps.csv")
well_df = pd.read_csv("../data/wellness.csv")

# %%
gps_df.head(20)
# Out:
#     GameID  Half  PlayerID  FrameID      Time GameClock     Speed  \
# 0        1     1         2        1  00:22:01  00:00:00  0.658334
# 1        1     1         2        2  00:22:01  00:00:00  0.594445
# 2        1     1         2        3  00:22:01  00:00:00  0.363889
# 3        1     1         2        4  00:22:01  00:00:00  0.444445
# 4        1     1         2        5  00:22:01  00:00:00  0.400000
# 5        1     1         2        6  00:22:01  00:00:00  0.000000
# 6        1     1         2        7  00:22:01  00:00:00  0.000000
# 7        1     1         2        8  00:22:01  00:00:00  0.000000
# 8        1     1         2        9  00:22:01  00:00:00  0.000000
# 9        1     1         2       10  00:22:02  00:00:01  0.000000
# 10       1     1         2       11  00:22:02  00:00:01  0.000000
# 11       1     1         2       12  00:22:02  00:00:01  0.000000
# 12       1     1         2       13  00:22:02  00:00:01  0.397223
# 13       1     1         2       14  00:22:02  00:00:01  0.372223
# 14       1     1         2       15  00:22:02  00:00:01  0.341667
# 15       1     1         2       16  00:22:02  00:00:01  0.372223
# 16       1     1         2       17  00:22:02  00:00:01  0.000000
# 17       1     1         2       18  00:22:02  00:00:01  0.000000
# 18       1     1         2       19  00:22:02  00:00:01  0.000000
# 19       1     1         2       20  00:22:03  00:00:02  0.000000
#
#     AccelImpulse  AccelLoad   AccelX   AccelY   AccelZ  Longitude   Latitude
# 0       0.611112   0.005330  0.13250  0.69875  0.56500  55.466666  24.994873
# 1       0.638889   0.006568  0.11125  0.92000  0.70625  55.466666  24.994874
# 2       2.305557   0.003114  0.01375  0.77000  0.67750  55.466667  24.994874
# 3       0.805556   0.002602  0.00625  0.88625  0.59500  55.466667  24.994874
# 4       0.444445   0.003813 -0.01750  0.85750  0.57375  55.466668  24.994874
# 5       4.000003   0.003036 -0.06375  0.90375  0.55125  55.466668  24.994874
# 6       0.000000   0.004433 -0.06875  1.01750  0.45375  55.466669  24.994874
# 7       0.000000   0.005419 -0.09750  1.08625  0.36500  55.466669  24.994874
# 8       0.000000   0.005841 -0.13000  0.88875  0.53625  55.466669  24.994874
# 9       0.000000   0.007465 -0.17750  0.85250  0.58875  55.466669  24.994874
# 10      0.000000   0.005549 -0.16750  0.90875  0.55250  55.466669  24.994874
# 11      0.000000   0.006431 -0.10875  0.91375  0.55875  55.466669  24.994873
# 12      3.972225   0.005079 -0.05875  0.86375  0.59250  55.466669  24.994873
# 13      0.250000   0.004044 -0.01375  0.84375  0.60375  55.466669  24.994872
# 14      0.305556   0.001518  0.05750  0.89500  0.61125  55.466669  24.994872
# 15      0.305556   0.002377  0.08250  0.87875  0.59250  55.466669  24.994872
# 16      3.722225   0.003826  0.12625  0.84000  0.61625  55.466669  24.994872
# 17      0.000000   0.004909  0.07625  0.94000  0.58000  55.466669  24.994872
# 18      0.000000   0.006530 -0.01125  0.86250  0.60500  55.466669  24.994872
# 19      0.000000   0.005651  0.10375  0.88250  0.58125  55.466669  24.994872

# %%
print(gps_df.shape)
# Out:
# (4570160, 14)

# %%
for i in gps_df['PlayerID'].unique():
    try:
        print(i)
        gps_df[(gps_df['GameID']==1) & (gps_df['PlayerID']==i)]['Speed'].plot.hist()
        print(gps_df[(gps_df['GameID']==1) & (gps_df['PlayerID']==i)]['Speed'].mean())
        plt.show()
    except:
        continue;
# Out:
# 2
# 0.7901562187455718
# 3
# 1.2858993408238548
# 4
# 0.7521661293289847
# 6
# 0.6449792878583427
# 7
# 1.378731298697114
# 8
# 1.0308786853215248
# 9
# 0.8654068743690558
# 10
# 1.5119686943000985
# 11
# 1.1329487680130474
# 12
# 1.5317121604417516
# 13
# 0.7086484389282381
# 17
# 0.39737165475116465
# 14
# 15
# 16
# 18
# 19
# 20
# 21
# 1
# 5

# %%
well_df.head()
# Out:
#          Date  PlayerID  Fatigue  Soreness  Desire  Irritability   BedTime  \
# 0  2018-07-21         1        3         3       2             3  23:00:00
# 1  2018-07-21         2        4         3       4             4  23:00:00
# 2  2018-07-21         3        3         3       5             4  22:30:00
# 3  2018-07-21         4        2         3       5             4  00:30:00
# 4  2018-07-21         5        5         3       4             4  23:45:00
#
#    WakeTime  SleepHours  SleepQuality  MonitoringScore Pain Illness  \
# 0  07:00:00        8.00             2               13   No      No
# 1  07:00:00        8.00             4               19  Yes      No
# 2  06:30:00        8.00             4               19   No      No
# 3  07:00:00        6.50             1               15   No      No
# 4  07:00:00        7.25             4               20   No      No
#
#   Menstruation  Nutrition NutritionAdjustment USGMeasurement    USG  \
# 0          Yes  Excellent                 Yes             No    NaN
# 1          Yes        NaN                 NaN            Yes  1.010
# 2           No        NaN                 NaN            Yes  1.016
# 3          Yes  Excellent                 Yes            Yes  1.025
# 4           No       Okay                 Yes            Yes  1.022
#
#   TrainingReadiness
# 0                0%
# 1                0%
# 2              100%
# 3               95%
# 4              100%

# %%
rpe_df.head()
# Out:
#          Date  PlayerID Training        SessionType  Duration  RPE  \
# 0  2018-07-21        13      Yes  Mobility/Recovery       5.0  0.0
# 1  2018-07-21        13      Yes               Game      29.0  7.0
# 2  2018-07-21        13      Yes               Game      27.0  9.0
# 3  2018-07-20        11      Yes               Game      36.0  6.0
# 4  2018-07-20        11      Yes               Game      36.0  8.0
#
#    SessionLoad  DailyLoad  AcuteLoad  ChronicLoad  AcuteChronicRatio  \
# 0          0.0      446.0      323.1       303.25               1.07
# 1        203.0        NaN        NaN          NaN                NaN
# 2        243.0        NaN        NaN          NaN                NaN
# 3        216.0      534.0      256.3       344.18               0.74
# 4        288.0        NaN        NaN          NaN                NaN
#
#    ObjectiveRating  FocusRating BestOutOfMyself
# 0              NaN          NaN      Not at all
# 1              NaN          NaN      Not at all
# 2              NaN          NaN      Not at all
# 3              9.0         10.0      Absolutely
# 4              9.0         10.0      Absolutely

# %%
games_df.head()
# Out:
#    GameID        Date Tournament  TournamentGame    Team   Opponent Outcome  \
# 0       1  2017-11-30      Dubai               1  Canada      Spain       W
# 1       2  2017-11-30      Dubai               2  Canada    Ireland       W
# 2       3  2017-11-30      Dubai               3  Canada       Fiji       W
# 3       4  2017-12-01      Dubai               4  Canada     France       W
# 4       5  2017-12-01      Dubai               5  Canada  Australia       L
#
#    TeamPoints  TeamPointsAllowed
# 0          19                  0
# 1          31                  0
# 2          31                 14
# 3          24                 19
# 4           7                 25

# %%
well_df[(well_df['Date']=='2017-11-30')][['Fatigue','PlayerID']]
# Out:
#       Fatigue  PlayerID
# 3183        2         1
# 3184        4         2
# 3185        5         3
# 3186        3         4
# 3187        4         5
# 3188        4         6
# 3189        5         7
# 3190        5         8
# 3191        4         9
# 3192        4        10
# 3193        4        11
# 3194        5        12
# 3195        4        13
# 3196        3        14
# 3197        1        16
# 3198        3        17

# %%
gps_df[(gps_df['GameID']==1) & (gps_df['PlayerID']==1)]['Speed'].mean()
# Out:
# nan

# %%
temp = gps_df[(gps_df['GameID']==1)].groupby("PlayerID").mean()[['Speed']].reset_index().merge(well_df[(well_df['Date']=='2017-11-30')][['Fatigue','PlayerID']],on="PlayerID")

# %%
temp = gps_df[
    (gps_df['GameID']==1)].groupby("PlayerID").mean()[
    ['Speed']].reset_index().merge(
    well_df[
        (well_df['Date']=='2017-11-30')][
        ['Fatigue','PlayerID']],on="PlayerID")

temp
# Out:
#     PlayerID     Speed  Fatigue
# 0          2  0.790156        4
# 1          3  1.285899        5
# 2          4  0.752166        3
# 3          6  0.644979        4
# 4          7  1.378731        5
# 5          8  1.030879        5
# 6          9  0.865407        4
# 7         10  1.511969        4
# 8         11  1.132949        4
# 9         12  1.531712        5
# 10        13  0.708648        4
# 11        17  0.397372        3

# %%
temp2 = games_df[['GameID','Date']].merge(well_df[['PlayerID','Fatigue','Date']],on='Date',how='outer')[['GameID','PlayerID','Fatigue']]
temp3 = gps_df[['GameID','PlayerID','Speed']].merge(temp2, on=['GameID','PlayerID'])
temp3
# Out:
#          GameID  PlayerID     Speed  Fatigue
# 0             1         2  0.658334        4
# 1             1         2  0.594445        4
# 2             1         2  0.363889        4
# 3             1         2  0.444445        4
# 4             1         2  0.400000        4
# 5             1         2  0.000000        4
# 6             1         2  0.000000        4
# 7             1         2  0.000000        4
# 8             1         2  0.000000        4
# 9             1         2  0.000000        4
# 10            1         2  0.000000        4
# 11            1         2  0.000000        4
# 12            1         2  0.397223        4
# 13            1         2  0.372223        4
# 14            1         2  0.341667        4
# 15            1         2  0.372223        4
# 16            1         2  0.000000        4
# 17            1         2  0.000000        4
# 18            1         2  0.000000        4
# 19            1         2  0.000000        4
# 20            1         2  0.000000        4
# 21            1         2  0.000000        4
# 22            1         2  0.000000        4
# 23            1         2  0.000000        4
# 24            1         2  0.000000        4
# 25            1         2  0.000000        4
# 26            1         2  0.000000        4
# 27            1         2  0.000000        4
# 28            1         2  0.000000        4
# 29            1         2  0.000000        4
# ...         ...       ...       ...      ...
# 4404631      38        16  1.169445        3
# 4404632      38        16  1.272223        3
# 4404633      38        16  1.086112        3
# 4404634      38        16  1.136112        3
# 4404635      38        16  1.202779        3
# 4404636      38        16  1.208334        3
# 4404637      38        16  1.211112        3
# 4404638      38        16  1.236112        3
# 4404639      38        16  1.133334        3
# 4404640      38        16  1.150001        3
# 4404641      38        16  1.150001        3
# 4404642      38        16  1.147223        3
# 4404643      38        16  1.263890        3
# 4404644      38        16  1.102779        3
# 4404645      38        16  1.072223        3
# 4404646      38        16  1.130556        3
# 4404647      38        16  1.180557        3
# 4404648      38        16  1.138890        3
# 4404649      38        16  1.125001        3
# 4404650      38        16  1.150001        3
# 4404651      38        16  1.150001        3
# 4404652      38        16  1.027779        3
# 4404653      38        16  1.097223        3
# 4404654      38        16  1.058334        3
# 4404655      38        16  1.150001        3
# 4404656      38        16  1.022223        3
# 4404657      38        16  0.977779        3
# 4404658      38        16  1.022223        3
# 4404659      38        16  1.055556        3
# 4404660      38        16  1.122223        3
#
# [4404661 rows x 4 columns]
